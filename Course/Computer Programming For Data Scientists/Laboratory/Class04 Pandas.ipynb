# %% [markdown]
# # Pandas

# %%
# Pandas is built on top of Numpy
#   it means that Pandas, in a very a raw level is actually nothing but Numpy array
#   pandas has added functionality, like dealing with misiing values, for example

# So why Numpy? Why not use Pandsa always?
# Pandas is MUCH slower than Numpy

# %% [markdown]
# ### Import Pandas

# %%
import pandas as pd
import numpy as np
# pd.__version__

# %% [markdown]
# # 1.Extract-Transform-Load (ETL)
# - Challegne : many data sources; maintain a lot of connectors; transform them to one single format

# %% [markdown]
# ## Load csv file

# %%
### the name of data that pandas called, is "Dataframe"
df = pd.read_csv('howlongwelive.csv')

# %% [markdown]
# ## Preview the dataframe

# %%
# you use df.head()
# format : df.head(number of rows; default is 5; you can also put negative numbers)
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
###as I say ,Pandas IS Numpy
df.shape

#means that there are 2938 rows , and 22 columns
# Out:
# (2938, 22)

# %%
#maybe you awnt a list of columns
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA)
# - looking at the distribution of data
# - plot something useful
# - understand the data
# - know which features to use
#
# Note **this is the MOST important step in all data science**

# %%
## releated seaborn
# df.info()

#list the datatypes of the dataframe
#key: we DON'T LIKE "object" ==> "string"

#so when you "object", you change it to numbers or drop it

# %%
#two ways to access rach column
# format1 : df['columname']
# format2 : df.columns
df['Status'] #try df.Status
# Out:
# 0       Developing
# 1       Developing
# 2       Developing
# 3       Developing
# 4       Developing
#            ...
# 2933    Developing
# 2934    Developing
# 2935    Developing
# 2936    Developing
# 2937    Developing
# Name: Status, Length: 2938, dtype: object

# %%
df['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
developing_cond = df['Status'] == 'Developing'
developed_cond = df['Status'] == 'Developed'

# %%
print(" Number of developing contries :",
    len(df.Status[developing_cond])) 

print(" Number of developed contries :", 
    len(df.Status[developed_cond]))
# Out:
#  Number of developing contries : 2426
#  Number of developed contries : 512

# %%
df.Status[developing_cond].shape[0]
# Out:
# 2426

# %%
# df.info()

# %%
df['Alcohol'].max(), df['Alcohol'].min(), df['Alcohol'].mean(), df['Alcohol'].median()
# Out:
# (17.87, 0.01, 4.602860787172012, 3.755)

# %%
df['Alcohol']
# Out:
# 0       0.01
# 1       0.01
# 2       0.01
# 3       0.01
# 4       0.01
#         ...
# 2933    4.36
# 2934    4.06
# 2935    4.43
# 2936    1.72
# 2937    1.68
# Name: Alcohol, Length: 2938, dtype: float64

# %%
#exercise1 : get the rows with alcohol more than the median
Morethan_median = df.Alcohol > df.Alcohol.median() #fancy_indexes
#List of country
df.Country[Morethan_median]
#and count
print("Counting Countries :",len(df.Country[Morethan_median].unique()))
#challeng : list the unique countries
print("Unique Countries :",df.Country[Morethan_median].unique())
# Out:
# Counting Countries : 106
# Unique Countries : ['Albania' 'Angola' 'Antigua and Barbuda' 'Argentina' 'Armenia'
#  'Australia' 'Austria' 'Bahamas' 'Barbados' 'Belarus' 'Belgium' 'Belize'
#  'Bolivia (Plurinational State of)' 'Bosnia and Herzegovina' 'Botswana'
#  'Brazil' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde' 'Cameroon'
#  'Canada' 'Chile' 'China' 'Colombia' 'Congo' 'Costa Rica' 'Croatia' 'Cuba'
#  'Cyprus' 'Czechia' 'Denmark' 'Dominican Republic' 'Ecuador'
#  'Equatorial Guinea' 'Estonia' 'Finland' 'France' 'Gabon' 'Georgia'
#  'Germany' 'Greece' 'Grenada' 'Guyana' 'Haiti' 'Hungary' 'Iceland'
#  'Ireland' 'Italy' 'Jamaica' 'Japan' 'Kazakhstan'
#  "Lao People's Democratic Republic" 'Latvia' 'Liberia' 'Lithuania'
#  'Luxembourg' 'Malta' 'Mauritius' 'Mexico' 'Mongolia' 'Montenegro'
#  'Namibia' 'Netherlands' 'New Zealand' 'Nicaragua' 'Nigeria' 'Norway'
#  'Panama' 'Paraguay' 'Peru' 'Philippines' 'Poland' 'Portugal'
#  'Republic of Korea' 'Republic of Moldova' 'Romania' 'Russian Federation'
#  'Rwanda' 'Saint Kitts and Nevis' 'Saint Lucia'
#  'Saint Vincent and the Grenadines' 'Samoa' 'Sao Tome and Principe'
#  'Serbia' 'Seychelles' 'Sierra Leone' 'Slovakia' 'Slovenia' 'South Africa'
#  'Spain' 'Suriname' 'Swaziland' 'Sweden' 'Switzerland' 'Thailand'
#  'Trinidad and Tobago' 'Uganda' 'Ukraine'
#  'United Kingdom of Great Britain and Northern Ireland'
#  'United Republic of Tanzania' 'United States of America' 'Uruguay'
#  'Venezuela (Bolivarian Republic of)' 'Viet Nam' 'Zimbabwe']

# %%
#exercise2: get the list of country
#with Schooling more than the meedian 
#and GDP more than the median
Scholing_morethan_Median = df.Schooling > df.Schooling.median()
print("Scholing Median :",df.Schooling[Scholing_morethan_Median].count())

GDP_morethan_Median  = df['GDP'] > df['GDP'].median()
print("GDP Medina :", df.GDP[GDP_morethan_Median].count())

## & and | or "pipe"
print("Counting Countries :", len(df.Country[(Scholing_morethan_Median & GDP_morethan_Median)].unique()))
print("Unique Countries :", df.Country[(Scholing_morethan_Median & GDP_morethan_Median)].unique())

type(df.Country[(Scholing_morethan_Median & GDP_morethan_Median)].unique())
# Out:
# Scholing Median : 1385
# GDP Medina : 1245
# Counting Countries : 96
# Unique Countries : ['Albania' 'Algeria' 'Antigua and Barbuda' 'Argentina' 'Armenia'
#  'Australia' 'Austria' 'Bahrain' 'Barbados' 'Belarus' 'Belgium' 'Belize'
#  'Bhutan' 'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'Brunei Darussalam'
#  'Bulgaria' 'Cabo Verde' 'Canada' 'Chile' 'China' 'Colombia' 'Costa Rica'
#  'Croatia' 'Cuba' 'Cyprus' 'Denmark' 'Dominican Republic' 'Ecuador'
#  'El Salvador' 'Estonia' 'Fiji' 'Finland' 'France' 'Gabon' 'Georgia'
#  'Germany' 'Greece' 'Grenada' 'Hungary' 'Iceland' 'Indonesia' 'Ireland'
#  'Israel' 'Italy' 'Jamaica' 'Japan' 'Jordan' 'Kazakhstan' 'Kuwait'
#  'Latvia' 'Lebanon' 'Libya' 'Lithuania' 'Luxembourg' 'Malaysia' 'Maldives'
#  'Malta' 'Mauritius' 'Mexico' 'Mongolia' 'Montenegro' 'Netherlands'
#  'New Zealand' 'Norway' 'Oman' 'Palau' 'Panama' 'Paraguay' 'Peru' 'Poland'
#  'Portugal' 'Qatar' 'Romania' 'Russian Federation' 'Samoa' 'Saudi Arabia'
#  'Serbia' 'Seychelles' 'Singapore' 'Slovenia' 'South Africa' 'Spain'
#  'Sri Lanka' 'Suriname' 'Sweden' 'Switzerland' 'Thailand' 'Tonga'
#  'Trinidad and Tobago' 'Tunisia' 'Turkey' 'Ukraine' 'United Arab Emirates'
#  'Uruguay']
# numpy.ndarray

# %%
#for any columns of countinuous value, it gives you count, mean, std, min, etc.
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
#use some easy libraby for visualization
# it accepts input as dataframe
import seaborn as sns
#seasorn: super easy library for visualization
#it's bulit on top of matplotlib
#matplotlib is the classic python library for visualization


#if I want to predict egg price , using gold and oil prics
#we called gold and oil prices MANY names
#   features, factor, independent variable, predictors, X
#   here, gold is called x_1, oil is called x_2
#we called, egg price MANY names
#   labels, targets, outcomes, dependent variable, y

# %%
#1. countplot is to plot the discrete x_1 or y
# sns.countplot(df.Status)
sns.countplot(data = df, x='Status')
# Out:
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
#2. distplot or displt is to plot the continous x_1 or y
sns.displot(df.Alcohol) #==> you get error, this is because your version is not > 0.10

#exercise: try displot for another continuous variable

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
sns.distplot(df.Alcohol) #old function
# Out:
# c:\Python3.10.4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Alcohol', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
'''
format: .rename(
    columns = 
    {
        oldname1: newname1,
        oldname2: newname2,
        oldname3: newname3
    }
)
'''
#tips: if you don't want to do df=,just put a argument inplace=True
#exercise: can you change 
# Income compostion of resoureces to income, 
# Schooling to schooling and 
# Status to status

df = df.rename(
    columns = 
    {
        'Life expectancy ': 'life_exp',
        'Income composition of resources': 'income',
        'Schooling': 'schooling',
        'Status': 'status'
    }
)

df.columns
# Out:
# Index(['Country', 'Year', 'status', 'life_exp', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years', 'income', 'schooling'],
#       dtype='object')

# %%
#Challenge: help clear all the spaces in the columns
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Country', 'Year', 'status', 'life_exp', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'income', 'schooling'],
#       dtype='object')

# %%
#3. boxplot is to plot discrete x_1 feautres vs continuous x_2/y
sns.boxplot(x = df['status'], y = df["life_exp"])
# Out:
# <AxesSubplot:xlabel='status', ylabel='life_exp'>

# %%
#4. scatterplot is to plot continuous x_1 vs continuous x_2/y
sns.scatterplot(x = df['Alcohol'], y = df['life_exp'], hue = df['status'])
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='life_exp'>

# %%
cols = df.columns
cols = np.array(cols)

type(cols)
cols
# Out:
# array(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure',
#        'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio',
#        'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP',
#        'Population', ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'], dtype=object)

# %%
#then I have to check how to remove
# cols = np.delete(cols,np.where(cols=='status'))
# cols = np.delete(cols,np.where(cols=='Country'))
# cols = np.delete(cols,np.where(cols=='life-exp'))
# cols = np.delete(cols,np.where(cols=='Year'))

cols = np.delete(cols,[np.where(cols=='status'),np.where(cols=='Country'),np.where(cols=='life_exp'),np.where(cols=='Year')])
cols
# Out:
# array(['Adult Mortality', 'infant deaths', 'Alcohol',
#        'percentage expenditure', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria',
#        'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'income', 'schooling'], dtype=object)

# %%
#exercise: find me this variables that have very strong correlation with life-exp
#get some column, but I akso have to drop some columns - drop status, drop country, drop life-exp
import matplotlib.pyplot as plt
for each_col in cols:
    # print(each_col)
    sns.scatterplot(x = df[each_col], y = df['life_exp'], hue = df['status'])
    plt.show()

# %%
#exercise: which features have almost NO relationship with life exp
# df.corr()

# %%
#exercise: try sns.heatmap(df.corr(), annot=True)
#df.corr() calculates the correlation between continuous features

#exercise: try to figure out how to increase the size of the figure
#(hint: you have to change using matplotlib figure size)

#1st way: use sns.set
#2nd way: use the figure size via the plt variable of matplotlib

plt.figure(figsize=(20, 20))
sns.heatmap(df.corr(),annot=True)

#0 is weak
#1,-1 is strong
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3. Preprocessing / Cleaning
# - The theory behind filling missing values
# - Dealing with outliers
#
# #### 3.1 Dealing with missing values
# - Case 1: **Continuous values**
#     - Repleace with:
#         - 1. **mean/median** if the distribution is normal
#         - 2. **median** if the distribution is NOT normal
#         - 3. **0** if 0 is every commmon occurence in the real-world
#         - 4. **regression** if your data fits nicely with regression, especaially linear regression
#     - Do we ever drop?
#         - almost never, drop columns lose a lot of values, dropping rows also lost other features...
#         - If you are super sure this is human mistake, you can drop
# - Case 2: **Discrete values**
#     - Replace with:
#         - 1. **Majority** - when majority is like 98%
#         - 2. **No category** - when we are not so sure
#         - 3. **Ratio** - preserve the shape of distrubution

# %%
#function for quickly check missing values
# df.isna().sum()

# df['life-exp'].isna().sum()

#this is my plan:

#features : income, schooling , statuts
#label : life-exp,

# %%
#typical steps to fill in missing value (continuous values)

#1. plot the distribution
#if your data is discrete, use countplot
plt.figure(figsize=(20, 6))
plt.subplot(1, 3, 1)
sns.distplot(df.income)
plt.subplot(1, 3, 2)
sns.distplot(df.schooling)
plt.subplot(1, 3, 3)
sns.distplot(df['life_exp'])

df.columns
# Out:
# c:\Python3.10.4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Python3.10.4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Python3.10.4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Index(['Country', 'Year', 'status', 'life_exp', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'income', 'schooling'],
#       dtype='object')

# %%
# sns.displot(df.income)
# sns.displot(df.schooling)
# sns.displot(df.life_exp)

# %%
#2. print mean and median
print(f'{df.income.mean(), df.income.median() = }')
print(f'{df.schooling.mean(), df.schooling.median() = }')
print(f'{df.life_exp.mean(), df.life_exp.median() = }')
# Out:
# df.income.mean(), df.income.median() = (0.6275510645976182, 0.677)
# df.schooling.mean(), df.schooling.median() = (11.992792792792793, 12.3)
# df.life_exp.mean(), df.life_exp.median() = (69.22493169398908, 72.1)

# %%
#3. judge by yourself mean or median bette, then fillna
# all things are median due to not normal distribution
df.income.fillna(df.income.median())

#you dont't have assign a variable to take the variable
#example : 1,2,3,3,100 -> mean = 22, median = 3

#excersie please fillna for schooling and life_exp
#make sure schooling.isna().sum() and life_exp.isna().sum() is 0

#1.plot the distribution
# let's asuume i plot already, and i found that median is a good representation
# good representation - high probability
df.income =  df.income.fillna(df.income.median())
df.schooling = df.schooling.fillna(df.schooling.median())
df.life_exp = df.life_exp.fillna(df.life_exp.median())

# print(f"{df.schooling.isna().sum(), df.life_exp.isna().sum() =}")

assert df.schooling.isna().sum() == 0
assert df.life_exp.isna().sum() == 0

# %%
#press B to quickly get new cell
#press D to quickly delete cell
#press M to cahnge to markdown

# %%
# df.isna().sum()

# %%
# cols = ['life_exp','income','schooling']

# for col in cols:
#     df[col].fillna(df[col].median(),inplace=True)

# assert df.income.isna().sum() == 0
# assert df.schooling.isna().sum() == 0
# assert df.life_exp.isna().sum() == 0

#one thing very important
#if you HAVE MISSING VALUES, when you run ML models
#   you will get error: Infinity NAN values
# if you want to drop the rows, use df[colname].dropna()

# %% [markdown]
# #### 3.2 Convert strings to number (float/int)
#
# - because ALL ML and DL models don't take strings
#     - data type error: Expected int/float but got strings
# - to quickly scan use info(), note the "objects"

# %%
# df.info()
#scan for dtype = object

# %%
df.status.unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %% [markdown]
# #### Theory/principle how tocenvert string to integer/float
# Three ways:
# 1. **Label encoding** : Just change to number:
#     1. Example: change developing to 0, developed to 1
#     2. Pros: super simple
#     3. Cons: imagine you got encoded 0, 1, 2, 3, 4, 5
#         1. You create a unwanted of order within this, e.g. 5>1
#         2. NEVER USE label encodiung uf you have more than two categories
# 2. **One-hot encoding** Pivot the values and make it become the columns
#     1. Delete the column "Status"
#     2. Put Developing as one column Developed as another column
#         1. if Developing is true, put 1 and then Developed column will be 0
#         2. if Developing is false, put 0 and then in the Developed column will be 1
# 3. **Sparse one-hot encoding** : if you have n columns of pivot, you can always delete 1 to save space.

# %%
##we want you convert status to 0 and 1
#easiest way is to use sk.learn.preprocessing import LabelEncoder

#1. import the library
from sklearn.preprocessing import LabelEncoder

#2. create the object
le = LabelEncoder()

#3. fit and transform
some_make_up_data = np.array(["Male", "Female", "Female","Male","Male", "Female"]) #===one column of df
result = le.fit_transform(some_make_up_data)

print(result)

#if you want to know which map to which, use le.inverse_transform(np.array([0,1]))
'''
le.fit_transform(some_make_up_data) 
=== 
le.fit(some_make_up_data)  #learn the mapping 
result = le.transform(some_make_up_data)
'''

#Exercise: please transform status using LabelEncoder
df.status = le.fit_transform(df.status)

#to know that what map to what
le.inverse_transform(np.array([0,1]))

#test that my transform is correct
assert len(df.status.unique()) == 2
#you can try something df.status.unique()) == [1.0]

#i want to tell the difference between fit snd transform
#fit mean learn the pattern
#transform mean transform the data
# Out:
# [1 0 0 1 1 0]

# %% [markdown]
# #### 3.3 Standardization / Normalization
#
# - i.e., we usually do splitting before any preprocessing
# - splitting - test train split before any preprocessing
#     - if you standardize
#     - if you fill missing value with some global statistics, you should split
#     - (it's ok to label encode)
# - when some knowleadge of the testing set flows to the training set, we call "data leakage" --> this is one of MOST COMMON MISTAKE of all beginners... like 99%

# %%
data = np.array([[1,5],[2,6],[3,7],[4,8]])

np.array([1,2,3,4]).std()
# Out:
# 1.118033988749895

# %%
#for each feature, do (x-mean)/std
#for the first feeature, mean = (1+2+3+4)/4 = 2.5
#   for the first data, do (1-2.5)/1.11 = -1.35
#   for the second data, do (2-2.5)/1.11 = -0.45

#after standardization, all features will have same scale
#all features mean = 0, std = 1
 
#1. import the library
from sklearn.preprocessing import StandardScaler

#2. create the object
sc = StandardScaler()
'''
The standard score of a sample x is calculated as: z = (x - u) / s
'''
#3. fit and transform
standardized_data = sc.fit_transform(data)
print(sc.mean_) #(1+2+3+4)/4 = 2.5 #(5+6+7+8)/4 = 6.5
print(standardized_data)

#when do you want to standardize your data:
#1. when you use regression, definitely yes - feautres importance
#2. in most classification algorithms (not distance-based algorithm), 
#   you benefit a bit from standardization
#3. your training will be more stable

#when you should NOT standardize data
#1. when the mean does not represent well your data
#   signal
#we can either do nothing or domin-max normalization
#from sklearn.preprocessing import MinMaxScaler #try this at your home
# (x-xmax)/(xmax-xmin) ==> (0,1)
#2.
# Out:
# [2.5 6.5]
# [[-1.34164079 -1.34164079]
#  [-0.4472136  -0.4472136 ]
#  [ 0.4472136   0.4472136 ]
#  [ 1.34164079  1.34164079]]

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'status', 'life_exp', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'income', 'schooling'],
#       dtype='object')

# %% [markdown]
# # 4. Feature Extraction / Selection
# - Sertiously consider which X and y to use for training

# %%
X =  df[['income','schooling','status']]
X.shape

#for X to be used with sklearn, it must be in the shape of (m,n)
#where m is number of samples, and n is number of ffeatures
# if you have only one feaeture, n=1 (e.g.m it cannot be (m,) ; MUST be (m,1))

assert X.shape[0] > 0
assert X.shape[1] > 0

# %%
y =  df[['life_exp']]
y.shape
#for y to be used with sklearn, if you only have one label
#the shape is (m, ) where m is number of samples
# Out:
# (2938, 1)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3, random_state=999)

# %%
#Please check the shape of X_train,X_test,y_train,y_test 
X_train.shape ,X_test.shape ,y_train.shape ,y_test.shape
# Out:
# ((2056, 3), (882, 3), (2056, 1), (882, 1))

# %%
import math
assert int(X.shape[0] * 0.7) == X_train.shape[0]
assert int(X.shape[0] * 0.7) == y_train.shape[0]
assert int(math.ceil(X.shape[0] * 0.3)) == X_test.shape[0]
assert int(math.ceil(X.shape[0] * 0.3)) == y_test.shape[0]

# %% [markdown]
# #### Fillna
# - I assume you already deleted fillna on top!

# %%
print("Before income: ", X_train['income'].median())
print("Before schooling: ", X_train['schooling'].median())

X_train['income'].fillna(X_train['income'].median(), inplace=True)
X_train['schooling'].fillna(X_train['schooling'].median(), inplace=True)

print("After income: ", X_train['income'].median())
print("After schooling: ", X_train['schooling'].median())

print("Before income test set: ", X_test['income'].median())
print("Before schooling test set: ", X_test['schooling'].median())

#use median of training set to fillna for testing set
X_test['income'].fillna(X_train['income'].median(), inplace=True)
X_test['schooling'].fillna(X_train['schooling'].median(), inplace=True)

print("After income test set: ", X_test['income'].median())
print("After schooling test set: ", X_test['schooling'].median())
# Out:
# Before income:  0.677
# Before schooling:  12.3
# After income:  0.677
# After schooling:  12.3
# Before income test set:  0.677
# Before schooling test set:  12.3
# After income test set:  0.677
# After schooling test set:  12.3

# %% [markdown]
# scaling

# %%
#now i want to show, let'say standardizatio, how to do
#please assume the same for any other preprocessing

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
y_train = sc.fit_transform(y_train)
y_test = sc.transform(y_test)

# %%
#Please assume the same for fillna

#Exercise
#i want you to restart this notebook, but now, fillna with median() 
# from the training set...

# df.income =  df.income.fillna(df.income.median())
# df.schooling = df.schooling.fillna(df.schooling.median())
#2. print mean and median

# %%
income_median = np.median(X_train[:,0])
schooling_median = np.median(X_train[:,1])
income_median, schooling_median

#hint: get the median first, before it got standardized,
#if not, the value you replaced is not valid
# Out:
# (0.23319474819931932, 0.09955562712522542)

# %%
assert X_train['income'].isna().sum() == 0
assert X_train['schooling'].isna().sum() == 0

assert X_test['income'].isna().sum() == 0
assert X_test['schooling'].isna().sum() == 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Guntsv\Downloads\AIT\AT82.01 Computer Programming for Data Science and Artificial Intelligence (PDS)\Coding-Along\Class4 Pandas.ipynb Cell 70 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Guntsv/Downloads/AIT/AT82.01%20Computer%20Programming%20for%20Data%20Science%20and%20Artificial%20Intelligence%20%28PDS%29/Coding-Along/Class4%20Pandas.ipynb#Y126sZmlsZQ%3D%3D?line=0'>1</a> assert X_train['income'].isna().sum() == 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Guntsv/Downloads/AIT/AT82.01%20Computer%20Programming%20for%20Data%20Science%20and%20Artificial%20Intelligence%20%28PDS%29/Coding-Along/Class4%20Pandas.ipynb#Y126sZmlsZQ%3D%3D?line=1'>2</a> assert X_train['schooling'].isna().sum() == 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Guntsv/Downloads/AIT/AT82.01%20Computer%20Programming%20for%20Data%20Science%20and%20Artificial%20Intelligence%20%28PDS%29/Coding-Along/Class4%20Pandas.ipynb#Y126sZmlsZQ%3D%3D?line=3'>4</a> assert X_test['income'].isna().sum() == 0
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
X_train[:,0].mean() , X_test[:,0].mean()
X_train[:,0].std() , X_test[:,0].std()

# %% [markdown]
# # The rest is NOT really Pandas job
# # 5. Training
# ### 1. cross validation, grid search
# # 6. Testing/ inference
# # 7. Deployment
