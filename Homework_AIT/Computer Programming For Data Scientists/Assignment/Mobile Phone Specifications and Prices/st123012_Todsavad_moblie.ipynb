# %% [markdown]
# # 1. ETL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("ndtv_data_final.csv")
df.head()
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                    4085                  6.67
# 1                  X2 Pro                    4000                  6.50
# 2       iPhone 11 Pro Max                    3969                  6.50
# 3               iPhone 11                    3110                  6.10
# 4               G8X ThinQ                    4000                  6.40
#
#   Touchscreen  Resolution x  Resolution y  Processor  ...  Rear camera  \
# 0         Yes          1440          3120          8  ...         48.0
# 1         Yes          1080          2400          8  ...         64.0
# 2         Yes          1242          2688          6  ...         12.0
# 3         Yes           828          1792          6  ...         12.0
# 4         Yes          1080          2340          8  ...         12.0
#
#    Front camera  Operating system  Wi-Fi Bluetooth  GPS Number of SIMs   3G  \
# 0          16.0           Android    Yes       Yes  Yes              2  Yes
# 1          16.0           Android    Yes       Yes  Yes              2  Yes
# 2          12.0               iOS    Yes       Yes  Yes              2  Yes
# 3          12.0               iOS    Yes       Yes  Yes              2  Yes
# 4          32.0           Android    Yes       Yes  Yes              1   No
#
#    4G/ LTE   Price
# 0      Yes   58998
# 1      Yes   27999
# 2      Yes  106900
# 3      Yes   62900
# 4       No   49990
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1359 non-null   int64
#  1   Name                    1359 non-null   object
#  2   Brand                   1359 non-null   object
#  3   Model                   1359 non-null   object
#  4   Battery capacity (mAh)  1359 non-null   int64
#  5   Screen size (inches)    1359 non-null   float64
#  6   Touchscreen             1359 non-null   object
#  7   Resolution x            1359 non-null   int64
#  8   Resolution y            1359 non-null   int64
#  9   Processor               1359 non-null   int64
#  10  RAM (MB)                1359 non-null   int64
#  11  Internal storage (GB)   1359 non-null   float64
#  12  Rear camera             1359 non-null   float64
#  13  Front camera            1359 non-null   float64
#  14  Operating system        1359 non-null   object
#  15  Wi-Fi                   1359 non-null   object
#  16  Bluetooth               1359 non-null   object
#  17  GPS                     1359 non-null   object
#  18  Number of SIMs          1359 non-null   int64
#  19  3G                      1359 non-null   object
#  20  4G/ LTE                 1359 non-null   object
#  21  Price                   1359 non-null   int64
# dtypes: float64(4), int64(8), object(10)
# memory usage: 233.7+ KB

# %%
df.shape
# Out:
# (1359, 22)

# %% [markdown]
# # 2.EDA

# %%
df.describe()
# Out:
#         Unnamed: 0  Battery capacity (mAh)  Screen size (inches)  \
# count  1359.000000             1359.000000           1359.000000
# mean    679.000000             2938.489330              5.291310
# std     392.453819              873.514133              0.671357
# min       0.000000             1010.000000              2.400000
# 25%     339.500000             2300.000000              5.000000
# 50%     679.000000             3000.000000              5.200000
# 75%    1018.500000             3500.000000              5.700000
# max    1358.000000             6000.000000              7.300000
#
#        Resolution x  Resolution y    Processor      RAM (MB)  \
# count   1359.000000   1359.000000  1359.000000   1359.000000
# mean     811.543046   1490.777778     5.551141   2488.777778
# std      270.707271    557.780120     2.196562   1664.440386
# min      240.000000    320.000000     1.000000     64.000000
# 25%      720.000000   1280.000000     4.000000   1000.000000
# 50%      720.000000   1280.000000     4.000000   2000.000000
# 75%     1080.000000   1920.000000     8.000000   3000.000000
# max     2160.000000   3840.000000    10.000000  12000.000000
#
#        Internal storage (GB)  Rear camera  Front camera  Number of SIMs  \
# count            1359.000000  1359.000000   1359.000000     1359.000000
# mean               30.654864    12.070199      7.037969        1.833701
# std                36.950241     8.948337      6.295448        0.374457
# min                 0.064000     0.000000      0.000000        1.000000
# 25%                 8.000000     8.000000      2.000000        2.000000
# 50%                16.000000    12.200000      5.000000        2.000000
# 75%                32.000000    13.000000      8.000000        2.000000
# max               512.000000   108.000000     48.000000        3.000000
#
#                Price
# count    1359.000000
# mean    11465.825607
# std     13857.497077
# min       494.000000
# 25%      4763.500000
# 50%      6999.000000
# 75%     11999.000000
# max    174990.000000

# %% [markdown]
# Note :
# - Battery is interesting
# - Ram
# - Internal Storage
# - Battery capacity (mAh)
# - IOS vs not IOS

# %% [markdown]
# #### checking Error value or converting

# %%
#Checking Operating System
df['Operating system'].unique()
# Out:
# array(['Android', 'iOS', 'Cyanogen', 'BlackBerry', 'Windows', 'Tizen',
#        'Sailfish'], dtype=object)

# %%
ios = df['Operating system'] == 'iOS'
noios = df['Operating system'] != 'iOS'

df['Operating system'][ios].count(),df['Operating system'][noios].count()
# Out:
# (17, 1342)

# %%
#converting Operating system
df['os'] = 1

# %%
df.loc[ios, 'os'] = 1
df.loc[noios, 'os'] = 0

# %%
df.os.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#checking is it Error value?
df[df['RAM (MB)'] <= 100]
# Out:
#      Unnamed: 0            Name  Brand     Model  Battery capacity (mAh)  \
# 443         443  Nokia Asha 502  Nokia  Asha 502                    1010
# 587         587  Nokia Asha 501  Nokia  Asha 501                    1200
#
#      Screen size (inches) Touchscreen  Resolution x  Resolution y  Processor  \
# 443                   3.0         Yes           240           320          1
# 587                   3.0         Yes           240           320          1
#
#      ...  Front camera  Operating system  Wi-Fi  Bluetooth GPS Number of SIMs  \
# 443  ...           0.0          Cyanogen    Yes        Yes  No              2
# 587  ...           0.0          Cyanogen    Yes        Yes  No              2
#
#      3G 4G/ LTE  Price os
# 443  No      No   3499  0
# 587  No      No   4999  0
#
# [2 rows x 23 columns]

# %%
#checking is it Error value?
df[df['Internal storage (GB)'] == 0.064]
# Out:
#      Unnamed: 0            Name  Brand     Model  Battery capacity (mAh)  \
# 443         443  Nokia Asha 502  Nokia  Asha 502                    1010
#
#      Screen size (inches) Touchscreen  Resolution x  Resolution y  Processor  \
# 443                   3.0         Yes           240           320          1
#
#      ...  Front camera  Operating system  Wi-Fi  Bluetooth GPS Number of SIMs  \
# 443  ...           0.0          Cyanogen    Yes        Yes  No              2
#
#      3G 4G/ LTE  Price os
# 443  No      No   3499  0
#
# [1 rows x 23 columns]

# %% [markdown]
# #### 2.1 Univariate Analysis
# - look at one variavle
# - main tools - countplot and displot
# - countplot for discrete features
# - displot for continuous features

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Brand', 'Model', 'Battery capacity (mAh)',
#        'Screen size (inches)', 'Touchscreen', 'Resolution x', 'Resolution y',
#        'Processor', 'RAM (MB)', 'Internal storage (GB)', 'Rear camera',
#        'Front camera', 'Operating system', 'Wi-Fi', 'Bluetooth', 'GPS',
#        'Number of SIMs', '3G', '4G/ LTE', 'Price', 'os'],
#       dtype='object')

# %%
df['RAM (MB)'].unique(),df['Internal storage (GB)'].unique(),df['Resolution x'].unique(),df['Resolution y'].unique(),df['Battery capacity (mAh)'].unique()
#All are discrete features
# Out:
# (array([12000,  6000,  4000,  8000,  3000,  2000,   512,  1000,    64,
#           384,   289,   256,   768], dtype=int64),
#  array([2.56e+02, 6.40e+01, 1.28e+02, 3.20e+01, 1.60e+01, 8.00e+00,
#         4.00e+00, 6.40e-02, 1.60e-01, 3.00e+00, 1.28e-01, 5.12e-01,
#         5.12e+02, 2.00e+00, 1.00e+00]),
#  array([1440, 1080, 1242,  828, 1125,  750,  720,  240, 2160,  640, 1600,
#          768, 1520,  540,  480, 1280,  850,  560,  360,  600, 1176,  400,
#         1536, 1880,  854,  800, 1024,  320], dtype=int64),
#  array([3120, 2400, 2688, 1792, 2340, 3040, 2436, 2960, 2160, 2240, 2280,
#         2246, 2560, 1334, 1920, 2880, 1280, 1600, 1560, 2520, 2248, 1520,
#         2310, 2220, 2244, 2316, 1440,  320, 3840, 1136, 1544, 1500,  720,
#         1620, 1480, 1080,  960,  854,  800,  480, 3200, 2636, 1548, 2152,
#         2270, 1580, 1498, 1290,  640, 1820,  584,  600,  485], dtype=int64),
#  array([4085, 4000, 3969, 3110, 3800, 4300, 6000, 3765, 4065, 4045, 4200,
#         3300, 3700, 2942, 2658, 3430, 2915, 3000, 5000, 3500, 3930, 1821,
#         2691, 2716, 2730, 3090, 3400, 3450, 2900, 1960, 3600, 3760, 2750,
#         2500, 3050, 2550, 3100, 4500, 4100, 4035, 4030, 4020, 3550, 3060,
#         3260, 3750, 3730, 3410, 3200, 4350, 3340, 3080, 2700, 3520, 2000,
#         5300, 4060, 3230, 3120, 3510, 2600, 2800, 4850, 1624, 4050, 2150,
#         1715, 4900, 2420, 3630, 2470, 3900, 3220, 2400, 1810, 2300, 2070,
#         1507, 2200, 2330, 2100, 4230, 3010, 3180, 3030, 3020, 3225, 4010,
#         4550, 3055, 5100, 3150, 3075, 2610, 2850, 5020, 2230, 2390, 1900,
#         1700, 1860, 1920, 2140, 1980, 2410, 2250, 2350, 1500, 1010, 2180,
#         1320, 2370, 1350, 1300, 1650, 1800, 4070, 3250, 2680, 2620, 2630,
#         3130, 2720, 2650, 2930, 1400, 2840, 1950, 2515, 2050, 2540, 1430,
#         3140, 2880, 1200, 1540, 1450, 4120, 3950, 3046, 4380, 3315, 3285,
#         2990, 3360, 3580, 1600, 2670, 1750, 2210, 2450, 1050, 1850, 3650,
#         2770, 2920, 4150, 2520, 1550, 2580, 2125, 2910, 2260, 2820, 1250],
#        dtype=int64))

# %%
#let's countplot
plt.figure(figsize=(30, 6))
plt.subplot(2, 3, 1)
sns.countplot(data = df, x ='Internal storage (GB)')
plt.subplot(2, 3, 2)
sns.countplot(data = df, x ='RAM (MB)')
plt.subplot(2, 3, 3)
sns.countplot(data = df, x ='Resolution x')
plt.subplot(2, 3, 4)
sns.countplot(data = df, x ='Resolution y')
plt.subplot(2, 3, 5)
sns.countplot(data = df, x ='os')
plt.subplot(2, 3, 6)
sns.countplot(data = df, x ='Battery capacity (mAh)')
# Out:
# <AxesSubplot:xlabel='Battery capacity (mAh)', ylabel='count'>

# %%
#let's displot 
sns.distplot(df['Screen size (inches)'])
# Screen size (inches) is continuous features
df['Screen size (inches)'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Guntsv\Downloads\AIT\AT82.01 Computer Programming for Data Science and Artificial Intelligence (PDS)\Coding-Along\st123012_Todsavad_moblie.ipynb Cell 21 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Guntsv/Downloads/AIT/AT82.01%20Computer%20Programming%20for%20Data%20Science%20and%20Artificial%20Intelligence%20%28PDS%29/Coding-Along/st123012_Todsavad_moblie.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> #let's displot
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Guntsv/Downloads/AIT/AT82.01%20Computer%20Programming%20for%20Data%20Science%20and%20Artificial%20Intelligence%20%28PDS%29/Coding-Along/st123012_Todsavad_moblie.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> sns.distplot(df['Screen size (inches)'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Guntsv/Downloads/AIT/AT82.01%20Computer%20Programming%20for%20Data%20Science%20and%20Artificial%20Intelligence%20%28PDS%29/Coding-Along/st123012_Todsavad_moblie.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> # Screen size (inches) is continuous features
#       <a href='vscode-notebook-cell:/c%3A/Users/Guntsv/Downloads/AIT/AT82.01%20Computer%20Programming%20for%20Data%20Science%20and%20Artificial%20Intelligence%20%28PDS%29/Coding-Along/st123012_Todsavad_moblie.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> df['Screen size (inches)'].unique()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# #### 2.2 Multivariate analysis
# - boxplot : for discrete vs continuous features
# - scatterplot : for continuous vs continuous features

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Brand', 'Model', 'Battery capacity (mAh)',
#        'Screen size (inches)', 'Touchscreen', 'Resolution x', 'Resolution y',
#        'Processor', 'RAM (MB)', 'Internal storage (GB)', 'Rear camera',
#        'Front camera', 'Operating system', 'Wi-Fi', 'Bluetooth', 'GPS',
#        'Number of SIMs', '3G', '4G/ LTE', 'Price', 'os'],
#       dtype='object')

# %%
#let's boxplot
sns.boxplot(x = df['Internal storage (GB)'], y= df['Price'])
# interesting storage has impacted the price
# Out:
# <AxesSubplot:xlabel='Internal storage (GB)', ylabel='Price'>

# %%
sns.boxplot(x = df['RAM (MB)'], y= df['Price'])
# interesting it follow up
# Out:
# <AxesSubplot:xlabel='RAM (MB)', ylabel='Price'>

# %%
sns.boxplot(x = df['Number of SIMs'],y=df['Price'])
#so so number of SIM 1 and 2 is almost similar
# Out:
# <AxesSubplot:xlabel='Number of SIMs', ylabel='Price'>

# %%
sns.boxplot(x = df['os'], y= df['Price'])
# so so because the price of noios(0) product still follow as expensive as ios(1)
# Out:
# <AxesSubplot:xlabel='os', ylabel='Price'>

# %%
sns.boxplot(x = df['Battery capacity (mAh)'], y= df['Price']) 
#so so it is quiet diverse
# Out:
# <AxesSubplot:xlabel='Battery capacity (mAh)', ylabel='Price'>

# %%
#let's scatterplot
sns.scatterplot(x = df['Screen size (inches)'], y=df['Price'])
# it is relational with price
# Out:
# <AxesSubplot:xlabel='Screen size (inches)', ylabel='Price'>

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#summary: Screen size (inches), Internal storage (GB), RAM (MB) is acceptable
# operating system in term of ios and noios is not good enough.
#Let's say those are best three as features

# %% [markdown]
# # 3.Feature Extraction / Selection

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Brand', 'Model', 'Battery capacity (mAh)',
#        'Screen size (inches)', 'Touchscreen', 'Resolution x', 'Resolution y',
#        'Processor', 'RAM (MB)', 'Internal storage (GB)', 'Rear camera',
#        'Front camera', 'Operating system', 'Wi-Fi', 'Bluetooth', 'GPS',
#        'Number of SIMs', '3G', '4G/ LTE', 'Price', 'os'],
#       dtype='object')

# %%
X =  df[['Screen size (inches)','Internal storage (GB)','RAM (MB)']]
y = df[['Price']]

assert X.shape[0] > 0
assert X.shape[1] > 0
assert y.shape[0] > 0

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=999)
#I use about 80 % of your data for training, and about 20 % of your data for test
#Because the data set is pretty much already.

# %%
X_train.shape, X_test.shape , y_train.shape, y_test.shape
# Out:
# ((1087, 3), (272, 3), (1087, 1), (272, 1))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1087 entries, 1154 to 348
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Screen size (inches)   1087 non-null   float64
#  1   Internal storage (GB)  1087 non-null   float64
#  2   RAM (MB)               1087 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 34.0 KB

# %%
y_train.info()
#All X_train and y_train is number already
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1087 entries, 1154 to 348
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1087 non-null   int64
# dtypes: int64(1)
# memory usage: 17.0 KB

# %% [markdown]
# # 4.Cleaning/Preprocessing
# - Fill - Standardize

# %% [markdown]
# ## 4.1 Fill (Features are not NULL)
# - check which one has contained the NULL value

# %%
X_train.isna().sum(), X_test.isna().sum()
# Out:
# (Screen size (inches)     0
#  Internal storage (GB)    0
#  RAM (MB)                 0
#  dtype: int64,
#  Screen size (inches)     0
#  Internal storage (GB)    0
#  RAM (MB)                 0
#  dtype: int64)

# %% [markdown]
# ## 4.2 Standardize Data
# - Normalized Data using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
#1. cretate the object
sc = StandardScaler()
#2. fit and transform the training set
X_train = sc.fit_transform(X_train)
#3. transform the test set
X_test = sc.transform(X_test)

y_train = sc.fit_transform(y_train)
y_test = sc.transform(y_test)

# %%
#checking Features mean is 0?
X_train[:,0].mean(),X_train[:,1].mean(),X_train[:,2].mean()
#All are 0
# Out:
# (-8.563118526639662e-16, 1.519790120186047e-16, 5.719640237259316e-17)
